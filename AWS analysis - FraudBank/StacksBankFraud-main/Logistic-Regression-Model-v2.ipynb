# %%
import pandas as pd

# %%
#read the csv file and save it in a variable called fraudbank_df
fraudbank_df = pd.read_csv('fraudTest-CSV.csv', sep=',')

# %%
fraudbank_df
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
#Make a dictionary that assigns a number to each category
#Map that dictionary into a new column of name: "category_num"

diccionario = {'travel': 1, 'shopping_pos': 2, 'shopping_net': 3, 'personal_care': 4, 'misc_pos': 5, 'misc_net': 6, 'kids_pets': 7, 'home': 8, 'health_fitness': 9, 'grocery_pos': 10, 'grocery_net': 11, 'gas_transport': 12, 'food_dining': 13, 'entertainment': 14}
fraudbank_df['category_num']= fraudbank_df['category'].map(diccionario)

#We do a .head to see if everything is fine
fraudbank_df.head(4)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
#
#        last gender                       street  ...      long city_pop  \
# 0   Elliott      M            351 Darlene Green  ...  -80.9355   333497
# 1  Williams      F             3638 Marsh Union  ... -110.4360      302
# 2     Lopez      F         9333 Valentine Point  ...  -73.5365    34496
# ...

# %%
def gender_bin(gender):
    if (gender == "M"):
        return 1
    else:
        return 0

# %%
fraudbank_df['gender_bin'] = fraudbank_df['gender'].apply(gender_bin)

# %%
fraudbank_df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ... city_pop  \
# 0   Elliott      M            351 Darlene Green  ...   333497
# 1  Williams      F             3638 Marsh Union  ...      302
# ...

# %%
fraudbank_df.dtypes
# Out:
# Unnamed: 0                 int64
# trans_date_trans_time     object
# cc_num                     int64
# merchant                  object
# category                  object
# amt                      float64
# first                     object
# last                      object
# gender                    object
# street                    object
# city                      object
# state                     object
# zip                        int64
# lat                      float64
# long                     float64
# city_pop                   int64
# job                       object
# dob                       object
# trans_num                 object
# unix_time                  int64
# merch_lat                float64
# merch_long               float64
# is_fraud                   int64
# category_num               int64
# gender_bin                 int64
# dtype: object

# %% [markdown]
# LOGISTIC REGRESSION MODEL

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE

# %%
x=fraudbank_df[['category_num', 'amt', 'gender_bin','zip','lat', 'long']]

y=fraudbank_df[['is_fraud']]

# %%
#split de los datos
X_train, X_test, y_train, y_test= train_test_split(x,y,test_size=0.30,random_state=101)

# %%
smote = SMOTE(random_state=101)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %% [markdown]
# We improved the model by oversampling the minority class

# %%
logisticmodel = LogisticRegression() #create the model
learn_data = logisticmodel.fit(X_train_resampled,y_train_resampled)   #learn from data
# Out:
# C:\Users\Valentin\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
predictions= logisticmodel.predict(X_test)

# %%
X_test
# Out:
#         category_num     amt  gender_bin    zip      lat      long
# 166998             9   18.13           0  71960  34.4596  -93.6743
# 437658            10  101.43           1  68723  42.2770  -97.1926
# 507291             6   13.72           0  58259  48.0204  -98.1186
# 97086             12   55.59           0  75661  32.6205  -94.2000
# 538606            12   76.82           0  53129  42.9373  -87.9943
# ...              ...     ...         ...    ...      ...       ...
# 17978              8   74.86           1  79085  34.7437 -102.5064
# 551699             2   12.72           0  28659  36.2017  -81.1286
# 430531             7   33.32           0   5733  43.8065  -73.0882
# 330633            11  102.59           0  28659  36.2017  -81.1286
# 411662             6    8.88           1  24983  37.5802  -80.5248
#
# [166716 rows x 6 columns]

# %%
predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
probabilities= learn_data.predict_proba(X_test)

# %%
probabilities
# Out:
# array([[0.77459385, 0.22540615],
#        [0.6688085 , 0.3311915 ],
#        [0.82774249, 0.17225751],
#        ...,
#        [0.79110781, 0.20889219],
#        [0.65888106, 0.34111894],
#        [0.81110075, 0.18889925]])

# %%
from sklearn.metrics import classification_report 
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score, roc_curve, auc
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle
from sklearn.metrics import f1_score, precision_score, recall_score, roc_auc_score, roc_curve, auc
from scipy import interp

# %%
accuracy_score(y_test,predictions)
# Out:
# 0.9458480289834209

# %%
precision_score(y_test,predictions, pos_label=1)
# Out:
# 0.0535352458142263

# %%
recall_score(y_test,predictions, pos_label=1)
# Out:
# 0.766412213740458

# %%
confusion_matrix(y_test, predictions)
#tru target.  No Fraude   157186    8875
#             Fraude      153       502
#                       No fraude  Fraude

#                    test target
# Out:
# array([[157186,   8875],
#        [   153,    502]], dtype=int64)

# %%
 
fpr, tpr, threshold = roc_curve(y_test, probabilities[:,1], pos_label=1)
roc_auc = auc(fpr, tpr)
 
plt.figure()
plt.plot(fpr, tpr, color='orange', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0,1], color='navy',  linestyle='--')
 
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
 
plt.show()
 
display()

# %% [markdown]
# The more the ROC curve hugs the upper left corner of the graph, the better the model is at categorizing the data

# %% [markdown]
# The receiver operating characteristic (ROC) curve is a useful tool for evaluating and analyzing the performance of a logistic regression model. The ROC curve shows the relationship between the true positive rate (TPR) and the false positive rate (FPR) as the model classification threshold is varied

# %%
from joblib import dump

# %%
dump(logisticmodel, 'LogisticRegressionModelFraudBankFinal.joblib')
# Out:
# ['LogisticRegressionModelFraudBankFinal.joblib']
